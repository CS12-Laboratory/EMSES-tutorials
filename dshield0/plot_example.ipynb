# %%
import emout
import numpy as np
import matplotlib.pyplot as plt
# from mypyplot_config import *
import scipy.constants as cn

# plt.rcParams["font.family"] = "DejaVu Sans"

# %%
data = emout.Emout()

# %%
data.j1z[-1, :, int(data.inp.ny//2), :].plot()

# %%
data.nd1p[0, :, int(data.inp.ny//2), :].plot(use_si=False)

# %%
data.phisp[-1, :, int(data.inp.ny//2), :].plot()
